# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
# Out:
# C:\Users\rorugan\AppData\Local\Temp\ipykernel_17316\3868265794.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df=pd.read_csv("IPL2023_Matches.csv",encoding="windows-1252")
df.head()
# Out:
#    match_no       city date_of_match  \
# 0         1  Ahmedabad     3/31/2023
# 1         2     Mohali      4/1/2023
# 2         3    Lucknow      4/1/2023
# 3         4  Hyderabad      4/2/2023
# 4         5  Bengaluru      4/2/2023
#
#                                                venue  \
# 0                              Narendra Modi Stadium
# 1       Punjab Cricket Association IS Bindra Stadium
# 2  Bharat Ratna Shri Atal Bihari Vajpayee Ekana C...
# 3                 Rajiv Gandhi International Stadium
# 4                              M.Chinnaswamy Stadium
#
#                      Home_team              Away_team  \
# 0               Gujarat Titans    Chennai Super Kings
# 1                 Punjab Kings  Kolkata Knight Riders
# 2         Lucknow Super Giants         Delhi Capitals
# 3          Sunrisers Hyderabad       Rajasthan Royals
# 4  Royal Challengers Bangalore         Mumbai Indians
#
#                    toss_winner                       winner man_of_the_match  \
# ...

# %%
df.shape
# Out:
# (70, 14)

# %%
df["man_of_the_match"].value_counts()
# Out:
# man_of_the_match
# Yashasvi Jaiswal       4
# Marcus Stoinis         3
# Shubman Gill           3
# Ravindra Jadeja        3
# Rinku Singh            2
# Suryakumar Yadav       2
# Varun Chakaravarthy    2
# Cameron Green          2
# Devon Conway           2
# Virat Kohli            2
# Mohit Sharma           2
# Nicholas Pooran        2
# Rashid Khan            2
# Faf du Plessis         2
# Jos Buttler            1
# Joshua Little          1
# Mitchell Marsh         1
# Mohammed Shami         1
# Draw                   1
# Ishan Kishan           1
# Matheesha Pathirana    1
# Philip Salt            1
# Shikhar Dhawan         1
# Krunal Pandya          1
# Andre Russell          1
# Mark Wood              1
# Prerak Mankad          1
# Prabhsimran Singh      1
# Wayne Parnell          1
# Rilee Rossouw          1
# Devdutt Padikkal       1
# Glenn Phillips         1
# Abhinav Manohar        1
# Axar Patel             1
# Ajinkya Rahane         1
# Rohit Sharma           1
# ...
